# %% [markdown]
# <a href="https://colab.research.google.com/github/mmopenat/Image_processing/blob/main/DataScence_Fifia_Players.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the dataset
file_path = "/content/fifa_players.csv"
df = pd.read_csv(file_path)

# Display basic information about the dataset
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17954 entries, 0 to 17953
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           17954 non-null  object
#  1   full_name                      17954 non-null  object
#  2   birth_date                     17954 non-null  object
#  3   age                            17954 non-null  int64
#  4   height_cm                      17954 non-null  float64
#  5   weight_kgs                     17954 non-null  float64
#  6   positions                      17954 non-null  object
#  7   nationality                    17954 non-null  object
#  8   overall_rating                 17954 non-null  int64
#  9   potential                      17954 non-null  int64
#  10  value_euro                     17699 non-null  float64
#  11  wage_euro                      17708 non-null  float64
# ...

# %%
# Step 1: Handle missing values

# Check missing values per column
missing_values = df.isnull().sum()

# Drop columns with excessive missing values (e.g., national team-related columns)
drop_columns = ["national_team", "national_rating", "national_team_position", "national_jersey_number"]
df_cleaned = df.drop(columns=drop_columns)

# Fill missing financial values (value_euro, wage_euro, release_clause_euro) with median values
financial_cols = ["value_euro", "wage_euro", "release_clause_euro"]
for col in financial_cols:
    df_cleaned[col] = df_cleaned[col].fillna(df_cleaned[col].median())

# Verify missing values after handling
df_cleaned.isnull().sum()
# Out:
# name                             0
# full_name                        0
# birth_date                       0
# age                              0
# height_cm                        0
# weight_kgs                       0
# positions                        0
# nationality                      0
# overall_rating                   0
# potential                        0
# value_euro                       0
# wage_euro                        0
# preferred_foot                   0
# international_reputation(1-5)    0
# weak_foot(1-5)                   0
# skill_moves(1-5)                 0
# body_type                        0
# release_clause_euro              0
# crossing                         0
# finishing                        0
# heading_accuracy                 0
# short_passing                    0
# volleys                          0
# dribbling                        0
# curve                            0
# freekick_accuracy                0
# long_passing                     0
# ...

# %% [markdown]
# # New Section
